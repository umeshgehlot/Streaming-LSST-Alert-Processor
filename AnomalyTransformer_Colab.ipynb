# %% [markdown]
# # Anomaly Transformer - Google Colab Runner
#
# This notebook allows you to run the Anomaly Transformer project using Google Colab and Google Drive.
#
# ### Steps:
# 1. **Upload your project folder** to your Google Drive root (the folder should be named `-Anomaly-Discovery-in-Astronomical`).
# 2. **Run the cells below** to connect your Drive and start training.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Navigate to Project Directory
# Change the path below if your folder name is different.

# %%
import os
# Update this path to match your folder location in Drive
project_path = '/content/drive/MyDrive/-Anomaly-Discovery-in-Astronomical'
if os.path.exists(project_path):
    os.chdir(project_path)
    print(f'Currently in: {os.getcwd()}')
    # !ls
else:
    print(f'ERROR: {project_path} not found. Please make sure you uploaded the folder to Drive.')

# %% [markdown]
# ### Start Training
# We use a batch size of 128 to ensure it fits in the Colab GPU memory.

# %%
# !python main.py --mode train --dataset SMD --data_path dataset/SMD/SMD --batch_size 128 --num_epochs 10
